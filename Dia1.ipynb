# %%
print('Hola mundo')
# Out:
# Hola mundo

# %%
# Orden de ejecucion:

fruta = "naranja"
print(fruta)

cantidad_de_frutas = 4
print(cantidad_de_frutas)

fruta = "banana"
print(fruta)
# Out:
# naranja
# 4
# banana

# %%
edad = 28 # --> Integer
altura = 1.80 # --> float
nombre = "Maggi" # --> String
feliz = True # --> bool

# print(edad)
# print(altura)
# print(nombre)
# print(feliz)

# ctl k y ctrl c / ctrl k y ctrl u para habilitar y deshabilitar la los comentarios

print(edad, altura, nombre, feliz)
# Out:
# 28 1.8 Maggi True

# %%
# variables
nombre = 'Carlos'
edad = 25
ciudad = 'Asunción'

print('Hola, soy', nombre, 'tengo', edad, 'años y vivo en la ciudad de', ciudad, '.')
# Out:
# Hola, soy Carlos tengo 25 años y vivo en la ciudad de Asunción .

# %%
# variables
producto1 = 'papas fritas'
costo_producto1 = 15000
producto2 = 'coca cola'
costo_producto2 = 14000
capital = 50000
dolar = 6700

# Realizamos la suma
costo_total = costo_producto1 + costo_producto2
print(costo_total)

# Realizamos la resta
vuelto = capital - costo_total
print(vuelto)

# Realizamos la multiplicacion
vuelto_dolar = vuelto/dolar
print(vuelto_dolar)
# Out:
# 29000
# 21000
# 3.1343283582089554

# %%
# variables
cantidad_de_manzanas = 5
cantidad_de_naranjas = 7
frutas_vendidas = 9

#suma
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
print('Frutas totales:', cantidad_de_frutas)

#resta
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print('Frutas restantes:', frutas_restantes)
# Out:
# Frutas totales: 12
# Frutas restantes: 3

# %%
# variables Strings
nombre = 'Maggi'
apellido = 'Ovelar'

print(nombre + apellido)

# Concatenar los strings
print(nombre + ' ' + apellido)

print(f'Hola me llamo {nombre}, y mi apellido es {apellido}')
# Out:
# MaggiOvelar
# Maggi Ovelar
# Hola me llamo Maggi, y mi apellido es Ovelar

# %%
#variables
nombre = 'Guillermo'
apellido = 'López'

print(f'Hola, me llamo {nombre} {apellido}. Mucho gusto.')

print(f'\n Hola, \n Me llamo {nombre} {apellido}. \n Mucho gusto xd')
# Out:
# Hola, me llamo Guillermo López. Mucho gusto.
#
#  Hola,
#  Me llamo Guillermo López.
#  Mucho gusto xd

# %%
nombre = input("Escribe tu nombre")
print(nombre)
# Out:
# carl

# %%
producto = input('Que producto deseas')
print(producto)

cantidad_de_producto = input('Que cantidad de producto deseas')
input(cantidad_de_producto)

print(f'El usuario quiere un/a {producto} en {cantidad_de_producto} cantidad/es')
# Out:
# mac
# El usuario quiere un/a mac en 2 cantidad/es

# %%
edad = 19
print(type(edad))

nombre = 'Claudia'
type(nombre)
# Out:
# str

# %%
edad = int(input('Cuantos anhos tienes'))
print(type(edad))
# Out:
# <class 'int'>

# %%
# Variables
peso_pasajero1 = float(input('Peso del pasajero 1'))
peso_pasajero2 = float(input('Peso del pasajero 2'))

# Suma
peso_pasajeros_total = peso_pasajero1 + peso_pasajero2
print(f'El pasajero 1 y el pasajero 2 suman en total {peso_pasajeros_total} kilogramos')
print(type(peso_pasajeros_total))
# Out:
# El pasajero 1 y el pasajero 2 suman en total 187.6 kilogramos
# <class 'float'>

# %%
# Aca definimos la funcion
def preparar_sandwich():
    print('Preparar un sandwich')
    print('Ya el sandwich esta casi listo')
#Aqui termina la funcion

# Aca le llamamos a la funcion
preparar_sandwich()
preparar_sandwich()
preparar_sandwich()
# Out:
# Preparar un sandwich
# Ya el sandwich esta casi listo
# Preparar un sandwich
# Ya el sandwich esta casi listo
# Preparar un sandwich
# Ya el sandwich esta casi listo

# %%
# Definicion de la funcion
def preparar_cafe():
    print('Calentar el agua')
    print('Colocar tres cucharaditas de café en la taza')
    print('Colocar el agua caliente en la taza')
    print('Revolver el contenido de la taza.')

# Llamadas a la funcion
preparar_cafe() # Primera llamada
preparar_cafe() # Segunda llamada
preparar_cafe() # Tercera llamada
# Out:
# Calentar el agua
# Colocar tres cucharaditas de café en la taza
# Colocar el agua caliente en la taza
# Revolver el contenido de la taza.
# Calentar el agua
# Colocar tres cucharaditas de café en la taza
# Colocar el agua caliente en la taza
# Revolver el contenido de la taza.
# Calentar el agua
# Colocar tres cucharaditas de café en la taza
# Colocar el agua caliente en la taza
# Revolver el contenido de la taza.

# %%
def preguntar_caracteristicas(celular):
    ram = int(input('Cuanta ram quieres que tenga tl celular'))
    memoria = int(input('Cuanta memoria quieres que tenga el celular'))
    bateria = int(input('De cuanto quieres que sea la bateria del celular'))
    print(f'Celular con {ram}gb de ram, {memoria}gb de memoria y {bateria}mAh de bateria')

preguntar_caracteristicas('celular')
# Out:
# Celular con 8gb de ram, 128gb de memoria y 7000mAh de bateria

# %%
def saludar():
    print('Hola')

saludar()
# Out:
# Hola

# %%
ARTICULO = 'Prenda de Vestir'

def preguntar_caracteristicas(ARTICULO):
    tipo_de_prenda = input('Que tipo de prenda prefieres?')
    tamanho = input('Que medida prefieres?')
    color = input('Cual color quieres?')
    print(f'Quieres comprar un/a {ARTICULO}, del tipo {tipo_de_prenda}, tamanho {tamanho}, del color {color}')

preguntar_caracteristicas('ARTICULO')
# Out:
# Quieres comprar un/a ARTICULO, del tipo remera, tamanho m, del color azul
