# %%
print('Hola')
# Out:
# Hola

# %%
def saludar():
    print('Hola')

saludar()
# Out:
# Hola

# %%
# Challenge

# Definir una variable llamada palabra
# Crear una funcion def imprimir_palabra()
    # Imprimir la variable palabra

# Llamar a la funcion para ejecutar

palabra= 'Hola'

#Definir la funcion
def imprimir_palabra():
    print(palabra)

# Llamar a la funcion que definimos
imprimir_palabra()
# Out:
# Hola

# %%
# Sumar 2 numeros:

# Definir 2 variables con int(input()), num1, num2 (fuera de la funcion)

# Definir la funcion sumar(n1, n2):
    # opcion1: n3 = n1 + n2
    # opcion1: print(n3)

    # opcion2: print(n1 + n2)

# Ejecutar a la funcion sumar(n1 + n2)

num1 = int(input('Ingresa un numero'))
num2 = int(input('Ingresa un numero'))

def sumar(n1, n2):
    n3 = n1 + n2
    print(n3)

sumar(num1, num2)
# Out:
# 7

# %%
# Crear variables
# letra1
# letra2

# Definir la funcion: def verificar_letra(x, y):
    # if x == y:
        # print(son iguales)
    # else:
        # print(son diferentes)

letra1 = input('Ingrese una letra')
letra2 = input('Ingrese una letra')

def verificar_letra(x, y):
    if x == y:
        print('Las letras son iguales')
    else:
        print('Las letras son diferentes')

verificar_letra(letra1, letra2)
# Out:
# Las letras son diferentes

# %%
letra1 = input('Ingrese una letra')

while True:
    letra2 = input('Ingrese una letra')
    if letra1 == letra2:
        print('Las letras son iguales')
        break
    else:
        letra1 != letra2
        print('Las letras son diferentes, vuelve a intentarlo')

# %%
# Return

def sumar(n1, n2):
    resultado = n1 + n2
    return resultado

print(type(sumar(1, 2)))

resultado_suma = sumar (5, 8)
# Out:
# 3

# %%
def retirar_dinero(dinero):
    return dinero

dinero_retirado = retirar_dinero(50000)
print(f'Este es el dato de dinero_retirado: {dinero_retirado}')

sumar(dinero_retirado, 10000)
# Out:
# Este es el dato de dinero_retirado: 50000
# 60000

# %%
palabra = input('Ingrese una palabra')
numero = int(input('Ingrese un numero'))

def comparador(pal, num):
    if len(pal) == num:
        return True
    else:
        return False
 
comparador(palabra, numero)
# Out:
# False

# %%
palabra1 = input('Ingrese una palabra')

def revisador(pal):
    for letra in pal:    
        if letra == 'd':
            return [letra]
        else:
            letra
    
revisador(palabra1)
# Out:
# ['d']

# %%
palabra1 = input('Ingrese una palabra')
cond = 'o'

def revisador(pal, letra):
    if letra in pal:
        return [letra]
    else:
        return letra
    
revisador(palabra1, cond)
# Out:
# 'o'

# %%
# challenge de Benja

la_letra = 'b'
user_input= input('palabrinha')

def the_word(word1):
    for i17 in word1:
        if i17 == la_letra:
            return [i17]
    return la_letra

the_word(user_input)

# %%
palabra_a_encontrar = input('Ingresa la pal')
print(f'Esta es la palabra')

# %%
# Pedir al usuario que ingrese 1 palabra, luego convertir esa palabra a una lista con sus caracteres con list().
# Agregar esa lista de caracteres a una lista llamada palabras_ingresadas. Repetir el proceso 3 veces.
# Cada vez que se agregue una lista de caracteres, imprimir la lista palabras_ingresadas.


# Ejemplo del resultado esperado:

# [['c', 'i', 'e', 'l', 'o']]
 # Al ingresar la primera palabra

# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
 # Al ingresar la segunda palabra

# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]
 # Al ingresar la tercera palabra

# %%
# definir una variable palabra= input()
# convertir palabra a lista con lista_de_palabra = list(palabra)

# creamos otra lista llamada: palabras_ingresadas = []
# palabras_ingresadas.append(lista_de_palabra)

# probar un bucle que repita 3 veces el proceso siguiente:

# %%
palabras_ingresadas = []
for i in range(3):
    palabra = input('Ingresa una palabra')
    lista_de_palabra = list(palabra)
    palabras_ingresadas.append(lista_de_palabra)
    print(palabras_ingresadas)
# Out:
# [['h', 'o', 'l', 'a']]
# [['h', 'o', 'l', 'a'], ['h', 'o', 'l', 'a']]
# [['h', 'o', 'l', 'a'], ['h', 'o', 'l', 'a'], ['h', 'o', 'l', 'a']]

# %%
palabra = input('Ingresa una palabra')
lista_de_palabra = list(palabra)

palabras_ingresadas = []
palabras_ingresadas.append(lista_de_palabra)
print(palabras_ingresadas)
# Out:
# [['h', 'o', 'l', 'a']]

# %%
palabras_ingresadas = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
for i in palabras_ingresadas:
    print(i)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
lista=[['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
def dar_enter():
    for i in lista:
        print(f"{i}\n")
dar_enter()
# Out:
# ['h', 'o', 'l', 'i', 's']
#
# ['h', 'e', 'l', 'l', 'o']
#
# ['h', 'a', 'l', 'l', 'o']

# %%
letras_verificadas = []
cantidad_letras = 5
palabra_secreta = 'salto'

def verificador_palabra(palabra_ingresada, palabra_secreta):
    for i in range(cantidad_letras):
        las_palabras_son_iguales = palabra_ingresada[i] == palabra_secreta[i] # True o False
        la_letra_existe_en_la_palabra = palabra_ingresada[i] in palabra_secreta

        if las_palabras_son_iguales:
            letras_verificadas.append(f'[{palabras_ingresadas[i]}]')
        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append(f'({palabras_ingresadas[i]})')
        else:
            letras_verificadas.append(palabras_ingresadas[i])

    return letras_verificadas

verificador_palabra('holas', 'calor')

# %%
# Intentos

# Definir la cantidad de intentos = variable
intentos = 0

while intentos <= 6:
    print(f'Te quedan {6 - intentos} intentos')
    intentos = intentos + 1
    palabra_ingresada = input('Ingrese una palabra')
    print(f'La palabra ingresada es: {palabra_ingresada}')
